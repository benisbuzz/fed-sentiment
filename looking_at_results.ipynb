# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import running_model as rm
from talib import MA, EMA

# %%
x = pd.read_parquet("data/results/fine_tune_prompt_2/fine_tune_prompt_2_speeches.parquet")

# %%
fig, ax = plt.subplots(figsize = (20,10))
ax.plot(x["hawk_score_1"].sort_index().dropna())
