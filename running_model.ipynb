# %%
import pandas as pd
import running_model as rm
import numpy as np
import os
from importlib import reload 
reload(rm)
# Out:
# <module 'running_model' from '/Users/benjamin/Documents/Projects/Code/Python/fed-sentiment/running_model.py'>

# %%
with open("data/data_scraping/important_words.txt", "r") as file:
    important_words = file.read().splitlines()

# %%
with open("data/prompts/fine_tune_prompt_2.txt", "r") as file:
    prompt = file.read().splitlines()

# %%
df = await rm.run_model(
    "data/data_scraping/scraped_data/speeches.parquet", 
    "data/results/fine_tune_prompt_2/fine_tune_prompt_2_speeches.parquet",
    important_words,
    os.getenv("FINE_TUNE_PROMPT_2"),
    prompt
    )
# Out:
# 2023-11-23 16:45:46 [info     ] data/results/fine_tune_prompt_2/fine_tune_prompt_2_speeches.parquet already created
# 2023-11-23 16:45:46 [info     ] got 2006-12-15 00:00:00, moving on
# 2023-11-23 16:45:46 [info     ] got 2006-12-01 00:00:00, moving on
# 2023-11-23 16:45:46 [info     ] got 2006-11-30 00:00:00, moving on
# 2023-11-23 16:45:46 [info     ] got 2006-11-28 00:00:00, moving on
# 2023-11-23 16:45:46 [info     ] got 2006-11-21 00:00:00, moving on
# 2023-11-23 16:45:46 [info     ] got 2006-11-16 00:00:00, moving on
# 2023-11-23 16:45:46 [info     ] got 2006-11-10 00:00:00, moving on
# 2023-11-23 16:45:46 [info     ] got 2006-11-03 00:00:00, moving on
# 2023-11-23 16:45:46 [info     ] got 2006-11-02 00:00:00, moving on
# 2023-11-23 16:45:46 [info     ] got 2006-11-01 00:00:00, moving on
# 2023-11-23 16:45:46 [info     ] got 2006-10-17 00:00:00, moving on
# 2023-11-23 16:45:46 [info     ] got 2006-10-16 00:00:00, moving on
# ...

# %%
df
# Out:
#                                    speaker  \
# date
# 2006-12-15        Chairman Ben S. Bernanke
# 2006-12-01        Chairman Ben S. Bernanke
# 2006-12-01    Vice Chairman Donald L. Kohn
# 2006-11-30     Governor Susan Schmidt Bies
# 2006-11-28        Chairman Ben S. Bernanke
# ...                                    ...
# 2023-01-20  Governor Christopher J. Waller
# 2023-01-19        Vice Chair Lael Brainard
# 2023-01-10     Governor Michelle W. Bowman
# 2023-01-10          Chair Jerome H. Powell
# 2023-01-06           Governor Lisa D. Cook
#
#                                                         title  \
# date
# 2006-12-15       The Chinese Economy: Progress and Challenges
# 2006-12-01                                  Welcoming remarks
# 2006-12-01                    Monetary Policy and Uncertainty
# 2006-11-30      A U.S. Perspective on Basel II Implementation
# 2006-11-28                               The Economic Outlook
# ...

# %%
df = pd.read_parquet("data/results/fine_tune_prompt_2/gpt-3.5-turbo_press_conferences.parquet")

# %%
await rm.call_from_df(df, important_words, "data/results/fine_tune_prompt_2/gpt-3.5-turbo_press_conferences.parquet", "gpt-3.5-turbo", prompt)
# Out:
# 2023-11-10 15:08:53 [info     ] got 2011-04-27 00:00:00, moving on
# 2023-11-10 15:08:53 [info     ] got 2011-06-22 00:00:00, moving on
# 2023-11-10 15:08:53 [info     ] got 2011-11-02 00:00:00, moving on
# 2023-11-10 15:08:53 [info     ] got 2012-01-25 00:00:00, moving on
# 2023-11-10 15:08:53 [info     ] got 2012-04-25 00:00:00, moving on
# 2023-11-10 15:08:53 [info     ] got 2012-06-20 00:00:00, moving on
# 2023-11-10 15:08:54 [info     ] 200
# 2023-11-10 15:08:54 [info     ] completed 11 / 253
# 2023-11-10 15:08:54 [info     ] 200
# 2023-11-10 15:08:54 [info     ] completed 13 / 253
# 2023-11-10 15:08:54 [info     ] 200
# 2023-11-10 15:08:54 [info     ] completed 9 / 253
# 2023-11-10 15:08:54 [info     ] 200
# 2023-11-10 15:08:54 [info     ] completed 5 / 253
# 2023-11-10 15:08:54 [info     ] 200
# 2023-11-10 15:08:54 [info     ] completed 4 / 253
# 2023-11-10 15:08:54 [info     ] 200
# 2023-11-10 15:08:54 [info     ] completed 10 / 253
# 2023-11-10 15:08:54 [info     ] 200
# ...
